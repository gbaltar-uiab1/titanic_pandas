# %% [markdown]
# # 🧩 Titanic Dataset Exploration with pandas
#
# 🎯 **Goal:**
# In this notebook, you'll explore the Titanic dataset using **pandas**.
# You'll practice the most common pandas functions for data inspection, selection, filtering, cleaning, and analysis.
#
# For each function in the list below:
# 1. Explain what it does (in your own words, in a Markdown cell).
# 2. Give at least **two examples** using the Titanic dataset.
# 3. Add a short comment about the output or why it’s useful.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Titanic dataset
# (Make sure titanic.csv is in the same folder as this notebook)
df = pd.read_csv("titanic_dataset.csv")

# Show first few rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# The above output shows the first few lines of a Dataframe called 'df'. We have created this Dataframe from the CSV file "titanic_dataset.csv".
# Since Pandas uses Dataframes as a native data structure we can now proceed with data handling operations, such as the aforementioned data inspection, selection, filtering, cleaning, and analysis.

# %% [markdown]
# ## 🧠 Step 1: Inspecting the Data
#
# In the previous code snippet we imported the pandas package with the alias 'pd'.
# The alias is a shorter name so it's used for convenience. The choice of the name 'pd' is standard amongst Python programmers.
#
# Next, we created an object called df. As previously mentioned, 'df' is a Pandas dataframe object containing the CSV file "titanic_dataset.csv".
#
# We shall now explore some basic Pandas methods leveraging our newly created *Dataframe* object.
#
#
# Functions to explore:
# - df.head()
#
# Shows the first n lines. By default (without parameters) is shows the last 5 lines.
#
#
#
# - df.tail()
#
# Shows the last n lines. By default (without parameters) is shows the last 5 lines.
#
#
# - df.info()
#
# Shows basic table info: Total entries, Columns, and non-null registers per column. It also provides info about what variables are used internally by Pandas to store each column.
#
#
# - df.describe()
#
# Shows basic statistics of the fields, such as aggregate sum (count), average value (mean), standard deviation (std) minimum value (min), distribution quartiles Q1 (25%), Q2 (50%), Q3 (75%), and maximum value (max).
# NB. This method will only consider columns whose internal variables are numerical (cf. df.info() above).
#
#
# - df.shape
#
# Shows the dimensions of the Dataframe (rows, columns) as a tuple.
#
# - df.columns
#
# Shows column names (labels).

# %%
# Show first 5 rows (default)
print(df.head())

print("\n\n\n\n\n\n")

# Show fist 10 rows
print(df.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
#
#
#
#
#
#
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Show last 5 rows (default)
print(df.tail())

# Shows last 10 rows
print(df.tail(10))
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
# Show column info (id, column tag, non-null count, data type)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Show basic stats -- for columns with numerical values

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Show number of rows and columns --> ( n_rows, n_columns)

df.shape
# Out:
# (891, 12)

# %%
# Show column labels

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## 🔍 Step 2: Selecting Data
#
# We shall demonstrate the ``` df["column"] ``` and ``` df.loc[] ``` Functions.
# <br><br>
#
# ###  ``` df["column"] ``` ``` df[["col1", "col2"]] ```
#
# Filters the Dataframe by column name.
#
#
# <br>
#
# ###  ``` df.loc[] ```
#
# A versatile, general-purpose indexer operation that uses labels for selection. It enables Selection and  Assignment operations by label (or slices thereof) alone, or as part of a conditional statement.
#
# The table below summarises the operation types supported along with examples.
#
#
# <table border="1" cellpadding="6" cellspacing="0">
#   <thead>
#     <tr>
#       <th>Category</th>
#       <th>Operation Type</th>
#       <th>Description</th>
#       <th>Examples</th>
#     </tr>
#   </thead>
#   <tbody>
#     <!-- Selection Category -->
#     <tr>
#       <td rowspan="2"><strong>Selection</strong></td>
#       <td>By label</td>
#       <td>Select rows, columns, or both by labels or label slices.</td>
#       <td>
#         <code>df.loc['row1']</code><br>
#         <code>df.loc[:, 'col1']</code><br>
#         <code>df.loc['row1', 'col1']</code><br>
#         <code>df.loc['row1':'row5', 'colA':'colC']</code>
#       </td>
#     </tr>
#     <tr>
#       <td>Conditional / Filtering</td>
#       <td>Select rows using a boolean mask based on a condition.</td>
#       <td>
#         <code>df.loc[df['age'] > 30]</code>
#       </td>
#     </tr>
#     <!-- Assignment Category -->
#     <tr>
#       <td rowspan="2"><strong>Assignment</strong></td>
#       <td>By label</td>
#       <td>Assign values directly using row/column labels.</td>
#       <td>
#         <code>df.loc['row1', 'col1'] = 42</code><br>
#         <code>df.loc['row2', ['colA','colB']] = ['x','y']</code>
#       </td>
#     </tr>
#     <tr>
#       <td>Conditional assignment</td>
#       <td>Assign values based on a condition (boolean mask).</td>
#       <td>
#         <code>df.loc[df['age'] > 30, 'status'] = 'Senior'</code>
#       </td>
#     </tr>
#     </table>
#
#   </tbody>
# </table>
#
#
#
# <br><br>
# ###  ``` df.iloc[] ```
#
# Selects rows and columns using integers. Supports
# index, index array and slicing
# - ``` df.iloc[0] ``` Shows the first row
# - ``` df.iloc[[0, 1, 4]] ``` Shows the 1st, 2nd and 5th rows
# - ``` df.iloc[:3] ``` Shows the first 3 rows (indices 0, 1, 2)

# %%
# Example: Selecting columns

# Single column selection
print(df["Age"].head())

# Multiple column selection
print(df[["Sex", "Age", "Survived"]].head())
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64
#       Sex   Age  Survived
# 0    male  22.0         0
# 1  female  38.0         1
# 2  female  26.0         1
# 3  female  35.0         1
# 4    male  35.0         0

# %%
# Cf. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html

# We're going to establish the percentages of Survivors and Deceased passengers.

'''
We could've used a simple row selection, boolean comparison and '.sum' to add up the resulting rows, thus;
    total_survivors = (df["Survived"] == 1).sum()
    total_deceased = (df["Survived"] == 0).sum()
However, for the sake of this exercise we'll be using '.loc' and '.shape'. 
```df.loc[ <boolean mask> ]``` selects matching rows. ``` .shape[0] ``` yields the row count.
'''


total_pax = len(df)
total_survivors = df.loc[df["Survived"] == 1].shape[0]
total_deceased  = df.loc[df["Survived"] == 0].shape[0]

print("Titanic's Pax and Survival general tally\n============================================\n")
print("Total passengers aboard the Titanic: ", total_pax)
print(f"Total survivors: {total_survivors}. ({(total_survivors / total_pax * 100):.2f}% of total passengers)")
print(f"Total deceased: {total_deceased}. ({(total_deceased / total_pax * 100):.2f}% of total passengers)")
# Out:
# Titanic's Pax and Survival general tally
# ============================================
#
# Total passengers aboard the Titanic:  891
# Total survivors: 342. (38.38% of total passengers)
# Total deceased: 549. (61.62% of total passengers)

# %%
'''
- ``` df.iloc[0] ``` Shows the first row
- ``` df.iloc[[0, 1, 4]] ``` Shows the 1st, 2nd and 5th rows
- ``` df.iloc[:3] ``` Shows the first 3 rows (indices 0, 1, 2)
'''

# Since 'Sex' and 'Age' columns are next to each other, we will make a small matrix sex_age_groups
#  first we slice both columns, then we fill up age_groups
#  we'll also check whether there are any data points left that do not satisfy the conditions (ie. (Male OR Female) AND (Child OR Adult) )


sex_age_groups = df.iloc[:, [1, 4, 5]]
print(sex_age_groups)


# how to simplify this?? Matrix??
# male_adult_survivor = sex_age_groups[sex_age_groups["Sex" == "male" ] and sex_age_groups["Age" >= 16] and sex_age_groups["Survived" == 1]].count


male     = sex_age_groups["Sex"] == "male"
female   = sex_age_groups["Sex"] == "female"
adult    = sex_age_groups["Age"] >= 16
child    = sex_age_groups["Age"] < 16
survived = sex_age_groups["Survived"] == 1
deceased = sex_age_groups["Survived"] == 0


male_adult_survivor      = sex_age_groups[male & adult & survived].shape[0]
female_adult_survivor    = sex_age_groups[female & adult & survived].shape[0]

male_adult_deceased      = sex_age_groups[male & adult & deceased].shape[0]
female_adult_deceased    = sex_age_groups[female & adult & deceased].shape[0]

male_child_survivor      = sex_age_groups[male & child & survived].shape[0]
female_child_survivor    = sex_age_groups[female & child & survived].shape[0]

male_child_deceased      = sex_age_groups[male & child & deceased].shape[0]
female_child_deceased    = sex_age_groups[female & child & deceased].shape[0]


print(f"Male adult survivor tally:\t{male_adult_survivor}")
print(f"Female adult survivor tally:\t{female_adult_survivor}")

print(f"Male adult deceased tally:\t{male_adult_deceased}")
print(f"Female adult deceased tally:\t{female_adult_deceased}")

print(f"Male child survivor tally:\t{male_child_survivor}")
print(f"Female child survivor tally:\t{female_child_survivor}")

print(f"Male child deceased tally:\t{male_child_deceased}")
print(f"Female child deceased tally:\t{female_child_deceased}")



# Plot deceased and survivor number for each category using a stacked bar chart.

# Transform the variables into a dictionary of lists (we need this to create a Dataframe)

segmented_data = {
    'Group' : ['Male Adult', 'Female Adult', 'Male Child', 'Female Child'],

    # Survivor counts (aligned with 'Group')
    'Survivor' : [male_adult_survivor, female_adult_survivor, male_child_survivor, female_child_survivor],

    # Deceased counts (aligned with 'Group')
    'Deceased' : [male_adult_deceased, female_adult_deceased, male_child_deceased, female_child_deceased]
}


# Create the Dataframe
df_segmented_data = pd.DataFrame(segmented_data)

df_segmented_data.head()

# Use 'Group' as Index
df_segmented_data = df_segmented_data.set_index('Group')


# Initialise Matplotlib plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the base of the stack (Deceased count values)
p1 = ax.bar(df_segmented_data.index, df_segmented_data['Deceased'], label='Deceased', color='#d62728')

# Plot the top of the stack (Survivor count values)
p2 = ax.bar(df_segmented_data.index, df_segmented_data['Survivor'], bottom=df_segmented_data['Deceased'], label='Survivor', color='#2ca02c')

# Write out labels and chart title
ax.set_ylabel('Count')
ax.set_title('Titanic Fate by Sex and Age Group (Stacked Bar Chart)')
ax.legend(title='Fate')


# Tidy up chart layout
plt.xticks(rotation=0)
plt.tight_layout()

# Save the figure
plt.savefig('titanic_stacked_bar_chart.png')





# female_adult_survivor
# male_adult_deceased
# female_adult_deceased
# male_child_survivor
# female_child_survivor
# male_child_deceased
# female_child_deceased

# Check if Total Count tallies to Total Pax (otherwise there's sth wrong in data!)
# Out:
#      Survived     Sex   Age
# 0           0    male  22.0
# 1           1  female  38.0
# 2           1  female  26.0
# 3           1  female  35.0
# 4           0    male  35.0
# ..        ...     ...   ...
# 886         0    male  27.0
# 887         1  female  19.0
# 888         0  female   NaN
# 889         1    male  26.0
# 890         0    male  32.0
#
# [891 rows x 3 columns]
# Male adult survivor tally:	72
# Female adult survivor tally:	169
# Male adult deceased tally:	341
# Female adult deceased tally:	49
# Male child survivor tally:	21
# Female child survivor tally:	28
# Male child deceased tally:	19
# Female child deceased tally:	15

# %% [markdown]
# From the above Stacked Chart we can easily see the following facts;
#
# - Male adults are by far the bucket with most casualties, roughly 75%.
#
# - Female adults' casualties are far fewer, slightly over 15%.
#
# These would be supporting arguments to the investigation's claim — that the  *Women and children first* evacuation policy was largely observed.
#
# - On children, survival rates go over 50% for males, slightly higher for females (65%).
#
#
# It's worth mentioning that although these facts would indeed support adherence to evacuation procedures, **one would expect ***female children*** to be the bucket with the highest survival rate**. But female adults win by 10%.<br>
# Explaining this would beg a deeper analysis, both in terms of segmentation ("*number crunching*") and alignment with the details we may know about the sinking, and coming up with new hypotheses to explain the figures. For instance, if we further segment each female bucket by 'Pclass' we could establish different alternative scenarios, for instance;
# 1. There was a bigger proportion of adult females in 1st class, which explains the higher survival rate due to a prompter access to safety.
# 2. Although the proportion of children in 3rd class was smaller, the disadvantage (being children, probably sleeping at time of accident while parents might be elsewhere, situation of chaos and rampage downstairs as people fought to climb above the flood...) would explain the higher rate.

# %% [markdown]
# ### Are we going too fast though? Is the data trustworthy as is?
#
# We haven't done any basic **quality checks** yet! Let's compare the number of total passengers within the dataframe 'df_segmented_data' with the total passengers (conveniently we saved the variable 'total_pax' earlier).

# %%
# We'll calculate total_segmented_pax from the lists in the dataframe 'df_segmented_data'
# Then we'll compare this value with 'total_pax' to ascertain whether the previous chart is reliable.

print("QUALITY CONTROL:")
print("=================\n")

total_segmented_pax = df_segmented_data['Survivor'].sum() + df_segmented_data['Deceased'].sum()
print(f"Total Segmented Pax: \t{total_segmented_pax} \t---> (all included in above Chart)")
print(f"Total Dataset Pax: \t{total_pax} \t---> (Total Dataset headcount)\n")

if total_segmented_pax < total_pax:
    print("Total Segmented Pax count is LOWER than Total Dataset Pax count!\nAnalysis is not 100 per cent reliable!")
    print(f"  Ratio of segmented pax vs total pax: {(total_segmented_pax / total_pax * 100):.2f}%")

elif total_segmented_pax > total_pax:
    print("Total Segmented Pax count is HIGHER than Total Dataset Pax count!\nAnalysis is not 100 per cent reliable!")
    print(f"  Ratio of segmented pax vs total pax: {(total_segmented_pax / total_pax * 100):.2f}%")

else:
    print("All registered passengers are included in the above Bar Chart")
# Out:
# QUALITY CONTROL:
# =================
#
# Total Segmented Pax: 	714 	---> (all included in above Chart)
# Total Dataset Pax: 	891 	---> (Total Dataset headcount)
#
# Total Segmented Pax count is LOWER than Total Dataset Pax count!
# Analysis is not 100 per cent reliable!
#   Ratio of segmented pax vs total pax: 80.13%

# %% [markdown]
# ## 🔎 Step 3: Filtering Rows
#
# Functions to explore:
# - df[df["Age"] > 30]
# - df.query("Sex == 'female' and Survived == 1")

# %%
# df[df["Age"] > 50].head()

''' This was already demonstrated. See above;

adult    = sex_age_groups["Age"] >= 16
child    = sex_age_groups["Age"] < 16

'''
# Out:
# ' This was already demonstrated. See above;\n\nadult    = sex_age_groups["Age"] >= 16\nchild    = sex_age_groups["Age"] < 16\n\n'

# %% [markdown]
# Using the ```df.query()``` method let's check the survival rate of Females in 1st class.
# - Pclass is the strongest survival predictor in the Titanic's sinking.
# - 1st class passengers have the highest survival rate due to having cabins closest to deck.
# - The evacuation protocol gave priority to women and children.
#
# We shall break down all females traveling 1st class as either **Unaccompanied** (traveling alone) or **Accompanied** (wives, daughters, sisters or mothers traveling with relatives), regardless of age. This splitting is meant as a simple way to have a test group —Conveniently for us, *Unaccompanied* amounts for about 1 third of the 1st Class female subset, while *Accompanied* contains the remaining two thirds.
#
# Thus, if the above premises are true, both groups  should have a similar ratio of survivors and deceased.
# To put this to the test, we chose a Mortality Rate (or Death Rate) metric.
#
# --> The results are indeed very close; **2.94%** and **3.33%** for the *Unaccompanied* and *Accompanied* groups, respectively.

# %%
# Let's assign vars for Unaccompanied female surviving and deceased pax in 1st class

unaccompanied_Fem_1st_survivors = df.query("Sex == 'female' and Survived == 1 and Pclass == 1 and SibSp == 0 and Parch == 0")
unaccompanied_Fem_1st_deceased = df.query("Sex == 'female' and Survived == 0 and Pclass == 1 and SibSp == 0 and Parch == 0")


# Get counts:
unaccompanied_Fem_1st_survivors_count = unaccompanied_Fem_1st_survivors.shape[0]
unaccompanied_Fem_1st_deceased_count = unaccompanied_Fem_1st_deceased.shape[0]


# Let's assign vars for Accompanied female surviving and deceased pax in 1st class

accompanied_Fem_1st_survivors = df.query("Sex == 'female' and Survived == 1 and Pclass == 1 and (SibSp > 0 or Parch > 0)")
accompanied_Fem_1st_deceased = df.query("Sex == 'female' and Survived == 0 and Pclass == 1 and (SibSp > 0 or Parch > 0)")


# Get counts:
accompanied_Fem_1st_survivors_count = accompanied_Fem_1st_survivors.shape[0]
accompanied_Fem_1st_deceased_count = accompanied_Fem_1st_deceased.shape[0]




# Mortality Rate
print("Mortality Rate (Females traveling 1st Class): [1]\n===================================================\n")
print(f"{'\033[1m'}Unaccompanied 1st class females{'\033[0m'}. Survivors: {unaccompanied_Fem_1st_survivors_count}, Deceased: {unaccompanied_Fem_1st_deceased_count}.\n\t Unaccompanied Mortality Rate:\t{(unaccompanied_Fem_1st_deceased_count / (unaccompanied_Fem_1st_deceased_count + unaccompanied_Fem_1st_survivors_count) * 100):.2f}%")
print(f"{'\033[1m'}Accompanied 1st class females{'\033[0m'}. Survivors: {accompanied_Fem_1st_survivors_count}, Deceased: {accompanied_Fem_1st_deceased_count}.\n\t Accompanied Mortality Rate:\t{(accompanied_Fem_1st_deceased_count / (accompanied_Fem_1st_deceased_count + accompanied_Fem_1st_survivors_count) * 100):.2f}%")

print(f"\n\n[1] Mortality Rate (or Death Rate) is the probability of death within each group;\n\t\t\tMortality Rate = Deceased # / Total in Category * 100")


# Odds of dying - Discarded metric
# print(f"{'\033[1m'}Unaccompanied 1st class females{'\033[0m'}. Survivors: {unaccompanied_Fem_1st_survivors_count}, Deceased: {unaccompanied_Fem_1st_deceased_count}. Deceased Ratio:\t{(unaccompanied_Fem_1st_deceased_count / unaccompanied_Fem_1st_survivors_count * 100):.2f}%")
# print(f"{'\033[1m'}Accompanied 1st class females{'\033[0m'}. Survivors: {accompanied_Fem_1st_survivors_count}, Deceased: {accompanied_Fem_1st_deceased_count}. Deceased Ratio:\t{(accompanied_Fem_1st_deceased_count / accompanied_Fem_1st_survivors_count * 100):.2f}%")
# Out:
# Mortality Rate (Females traveling 1st Class): [1]
# ===================================================
#
# Unaccompanied 1st class females. Survivors: 33, Deceased: 1.
# 	 Unaccompanied Mortality Rate:	2.94%
# Accompanied 1st class females. Survivors: 58, Deceased: 2.
# 	 Accompanied Mortality Rate:	3.33%
#
#
# [1] Mortality Rate (or Death Rate) is the probability of death within each group;
# 			Mortality Rate = Deceased # / Total in Category * 100

# %% [markdown]
# ## 🧹 Step 4: Handling Missing Data
#
# Functions to explore:
# - df.isna()
# - df.isna().sum()
# - df.dropna()
# - df.fillna()

# %% [markdown]
# ### Missing rows
#
# As we mentioned earlier, the total rows in the original dataset is **891**, but the segmented tally is **714**.
#
# The reason for this discrepancy is easily detected if we trace back the steps taken and we look at the output of the Pandas features explored so far.
#
# There is a row that has only 714 non-null rows, i.e. 'Age'.
# This information became apparent when we issued ```df.info()```.
#
# As we Later split and filtered our data by values of 'Age',  only the 714 non-null rows were carried forward;
#
# ```adult    = sex_age_groups["Age"] >= 16```<br>
# ```child    = sex_age_groups["Age"] < 16```

# %%
print("Showing non-null rows per column using df.info()\n")
print(df.info())
# Out:
# Showing non-null rows per column using df.info()
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %% [markdown]
# ### Data Cleaning Strategy
#
# There are 3 non-conforming columns, namely;
# - ***'Age'*** with some 200 missing entries and quantitative data
# <br>--> We can fill out with the mean value of Age.
# - ***'Cabin'*** has only 204 valid entries out of 891
# <br>--> Since valid entries are so scarce here, *we will drop (remove) this Column*.
# - ***'Embarked'*** only has 2 missing entries. Data is qualitative
# <br>--> We'll fill up the missing entries with the most frequent value.

# %% [markdown]
# Let's now take action on those missing records.
#
# ```df.isna()``` shows ```True``` for each null value in the Dataframe.
#
# ```df.isna().sum()``` shows the total of Null vales for each column.

# %%
# Example: Check missing values

print(df.isna())

print(df.isna().sum())
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill missing values in 'Age' with column median value.

df["Age"] = df["Age"].fillna(df["Age"].median())
df["Age"].head()

# Fill missing values in 'Embarked' with most frequent value
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# Note that 'Age' has now 891 non-null values as we've filled its null values with the column's median value.
# Note also this doesn't affect other columns with Null values, such as 'Cabin'
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %% [markdown]
# ```df.dropna()```<br>
# ```df.drop()```
#
# The column 'Cabin' has only 204 values. This is roughly 23% of the dataset row count.
# With such small amount of valid rows we are unable to fill in the remaining 73% and make this row's information meaningful.
#
# So, let's drop the column 'Cabin' using ```df.drop()```.
#
# <font color="red">NB. I've added ```df.drop()``` to this section.<br>To be honest, I don't quite see what I could do with ```df.dropna()``` as it seems to drop entire rows (not useful here), or columns(though it doesn't remove the column label, so what gives?).</font>

# %%
# try with wrong name
# df.drop('column_name', axis=1, inplace=False)

# Let's drop the column 'Cabin' with df.drop()
#   but ONLY if the column still exists.

if 'Cabin' in df.columns:
    print("Column 'Cabin' exists. Deleting...")
    df.drop('Cabin', axis=1, inplace=True)
    print("Column 'Cabin' deleted!")
else:
    print("Column 'Cabin' doesn't exist. No action taken.")

# Show resulting Dataframe's head.
df.head()
# Out:
# Column 'Cabin' exists. Deleting...
# Column 'Cabin' deleted!
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# ## 📊 Step 5: Grouping and Aggregating
#
# Functions to explore:
# - df.groupby("Sex")["Survived"].mean()
# - df["Fare"].mean()
# - df["Age"].median()

# %% [markdown]
# Let's show the how the ```groupby``` method allows us to quickly filter and select.
# For instance, we can see the Survivors and Deceased by Sex.

# %%
# Example: Aggregation
print("Survivors (%)\n==============")
print(df.groupby("Sex")["Survived"].mean() * 100)
print("\nDeceased (%)\n=============")
print((1 - df.groupby("Sex")["Survived"].mean()) * 100)
print("\nAverage ticket fare by Pax Class (£s. at 1912 value)\n=====================================================")
print(df.groupby("Pclass")["Fare"].mean())
# Out:
# Survivors (%)
# ==============
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64
#
# Deceased (%)
# =============
# Sex
# female    25.796178
# male      81.109185
# Name: Survived, dtype: float64
#
# Average ticket fare by Pax Class (£s. at 1912 value)
# =====================================================
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# Needless to say, by leveraging this handy method we're now using far fewer variables and lines of code.

# %% [markdown]
# Let's demonstrate ```df.median()```, which is an alternative to the average calculation ```df.mean()```.
#
# The output (mean: 29 years, median: 28) shows that;
# - There aren't significant outliers pulling the mean value too far off
# - The distribution is slightly skewed to the right (the mean is greater than the median)
# - Half of the Titanic's passengers were younger than 29 years old.

# %%
# Passenger age median
MEAN_AGE = print("Average passenger age:", df["Age"].mean(),"years")
MEDIAN_AGE = print("Median passenger age:", df["Age"].median(),"years")
# Out:
# Average passenger age: 29.36158249158249 years
# Median passenger age: 28.0 years

# %% [markdown]
# Let's create a subset and plot the ages to see the age distribution visually.

# %%
# Load the dataset (assuming df is already loaded)
df_clean_age = df.dropna(subset=['Age']).copy()


MEAN_AGE = df_clean_age['Age'].mean()
MEDIAN_AGE = df_clean_age['Age'].median()

fig, ax = plt.subplots(figsize=(10, 6))
bins = 30

# 1. Plot the part of the distribution <= Median (Blue)
ages_left = df_clean_age[df_clean_age['Age'] <= MEDIAN_AGE]['Age']
ax.hist(ages_left, bins=bins, color='skyblue', alpha=0.9, label='Age <= Median (28.0)', zorder=2)

# 2. Plot the part of the distribution > Median (Red)
ages_right = df_clean_age[df_clean_age['Age'] > MEDIAN_AGE]['Age']
ax.hist(ages_right, bins=bins, color='salmon', alpha=0.9, label='Age > Median (28.0)', zorder=2)

# 3. Median Line
ax.axvline(MEDIAN_AGE, color='black', linestyle='--', linewidth=2, label=f'Median ({MEDIAN_AGE:.1f})', zorder=3)

# 4. Mean Line
ax.axvline(MEAN_AGE, color='green', linestyle='-', linewidth=2, label=f'Mean ({MEAN_AGE:.1f})', zorder=3)

ax.set_title('Titanic Passenger Age Distribution')
ax.set_xlabel('Age (Years)')
ax.set_ylabel('No. of Passengers')
ax.legend(title='Legend', loc='upper right')
plt.tight_layout()
plt.savefig('titanic_age_distribution_split.png')

# %% [markdown]
# Let's query the original Dataframe to double-check whether there are so many passengers aged 28.

# %%
df['Age'].value_counts().head(5)
# Out:
# Age
# 28.0    202
# 24.0     30
# 22.0     27
# 18.0     26
# 30.0     25
# Name: count, dtype: int64

# %% [markdown]
# ## 📈 Step 6: Sorting and Counting
#
# Functions to explore:
# - df.sort_values("Age")
# - df["Sex"].unique()
# - df["Pclass"].value_counts()

# %% [markdown]
# - ```df.sort_values("Column")``` allows us to sort the rows by a certain column.
# - ```df["Column"].unique``` shows unique values for that row (Cf. Microsoft Excel's *UNIQUE* function, SQL's *SELECT DISTINCT* statement, etc.)
# - ```df["Column"].value_counts()``` counts total rows for each unique value of a given Column

# %% [markdown]
# Let's find the 10 oldest survivors using ```df.sort_values()```.
#
# Not surprisingly, most belong in 1st class.

# %%
df.sort_values("Age", ascending=False).query("Survived == 1").head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 483          484         1       3
# 275          276         1       1
# 570          571         1       2
# 829          830         1       1
# 587          588         1       1
# 366          367         1       1
# 268          269         1       1
# 11            12         1       1
# 195          196         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 630              Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 570                                Harris, Mr. George    male  62.0      0
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 587                  Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 268     Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 195                              Lurette, Miss. Elise  female  58.0      0
#
#      Parch       Ticket      Fare Embarked
# 630      0        27042   30.0000        S
# 483      0         4134    9.5875        S
# 275      0        13502   77.9583        S
# 570      0  S.W./PP 752   10.5000        S
# 829      0       113572   80.0000        S
# 587      1        13567   79.2000        C
# 366      0       110813   75.2500        C
# 268      1     PC 17582  153.4625        S
# 11       0       113783   26.5500        S
# 195      0     PC 17569  146.5208        C

# %% [markdown]
# Let's use ```df["Column"].unique()``` to verify the columns "Sex" and "Embarked" were cleaned correctly (ie. value 'nan' should no longer appear).

# %%
# Show Unique values

print("\n\nUnique values of column 'Sex':\n===============================")
print(df["Sex"].unique())

print("\nUnique values of column 'Embarked':\n====================================")
print(df["Embarked"].unique())
# Out:
# Unique values of column 'Sex':
# ===============================
# ['male' 'female']
#
# Unique values of column 'Embarked':
# ====================================
# ['S' 'C' 'Q']

# %% [markdown]
# Let's print the total counts of columns with unique values using ```df["Column"].value_counts()```

# %%
# Value counts 

print("\n\nValue counts for Unique values of column 'Pclass':\n===================================================")
print(df["Pclass"].value_counts())

print("\nValue counts for Unique values of column 'Embarked':\n=====================================================")
print(df["Embarked"].value_counts())
# Out:
# Value counts for Unique values of column 'Pclass':
# ===================================================
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
#
# Value counts for Unique values of column 'Embarked':
# =====================================================
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ## ⚙️ Step 7: Creating or Modifying Columns
#
# Functions to explore:
# - df.assign()
# - df.apply()
# - df["new_col"] = ...
# - pd.concat()
# - pd.merge()

# %% [markdown]
# ```df.assign()``` allows us to chain operations (*method chaining*). Returns a new dataframe so it doesn't modify the original.
#
# For instance, let's see how much is the ticket fare per passenger.

# %%
df_fares = df.assign(
    family_size = df['SibSp'] + df['Parch'] + 1,
    price_per_person = lambda x: x['Fare'] / x['family_size']
)

df_fares.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  family_size  price_per_person
# 0      0         A/5 21171   7.2500        S            2           3.62500
# 1      0          PC 17599  71.2833        C            2          35.64165
# 2      0  STON/O2. 3101282   7.9250        S            1           7.92500
# 3      0            113803  53.1000        S            2          26.55000
# 4      0            373450   8.0500        S            1           8.05000

# %% [markdown]
# ```df.apply()``` allows to embed a lambda function at row or column level. This adds conditional functionality.
#
# For instance, let's create a new column "Child" as a flag (boolean value).

# %%
# Creates the IsChild flag using a lambda function applied element-wise to the 'Age' column

df['Child'] = df['Age'].apply(lambda x: 1 if x < 16 else 0)

# Let's check if it Pandas created a boolean type for column "Child"
df.info()

# It took 'int64'. Let's recast to bool
df['Child'] = df['Child'].astype('bool')

# Check type is fixed
print("\n 'Child' column type recast, current Dtype is: ", (df['Child'].dtype))

# View the survival rate of chidren and adults

print('''\nSurvival rates of non-children (Adults) and children
(N.B.False for Adults, True for Children)
======================================================''')
print((df.groupby('Child')['Survived'].mean()) * 100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
#  11  Child        891 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB
#
#  'Child' column type recast, current Dtype is:  bool
#
# Survival rates of non-children (Adults) and children
# (N.B.False for Adults, True for Children)
# ======================================================
# Child
# False    36.262376
# True     59.036145
# Name: Survived, dtype: float64

# %%
# Example: Create new column
df["Fare_per_Age"] = df["Fare"] / df["Age"]
df[["Age", "Fare", "Fare_per_Age"]].head()
# Out:
#     Age     Fare  Fare_per_Age
# 0  22.0   7.2500      0.329545
# 1  38.0  71.2833      1.875876
# 2  26.0   7.9250      0.304808
# 3  35.0  53.1000      1.517143
# 4  35.0   8.0500      0.230000

# %% [markdown]
# ```df["new_col"] = ``` is the standard, straightforward way to create a new column.
#
# Let's create a "Title" column by extracting the text section between the comma and the dot characters in the "Name" column (ie. "Mr.", "Mrs.", and so on).

# %%
# Created new column "Title" to contain the passenger's form of address

df['Title'] = df['Name'].str.extract('\\, ([A-Za-z]+)\\.')

df['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Don           1
# Mme           1
# Ms            1
# Sir           1
# Lady          1
# Capt          1
# Jonkheer      1
# Name: count, dtype: int64

# %% [markdown]
# ```pd.concat()``` concatenates dataframes.
#
# Syntax: ``` new_df = pd.contact([df1, df2, ...], axis=0/1)```<br>
#   (```axis = 0``` for rows, ```axis = 1``` for columns)

# %%
# Split Dataframe into 3 by passenger class

df_class1 = df.query('Pclass == 1')
df_class2 = df.query('Pclass == 2')
df_class3 = df.query('Pclass == 3')

# Show head of 1 just for testing

df_class2.head()

# Now we stitch them together to prove this works
df_by_class = pd.concat([df_class1, df_class2, df_class3], axis=0)

# Head should show class 1 rows , and tail class 3 ones. 
print(df_by_class.head())
print(df_by_class.tail())
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Embarked  Child  Fare_per_Age Title
# 1       0  PC 17599  71.2833        C  False      1.875876   Mrs
# 3       0    113803  53.1000        S  False      1.517143   Mrs
# 6       0     17463  51.8625        S  False      0.960417    Mr
# 11      0    113783  26.5500        S  False      0.457759  Miss
# 23      0    113788  35.5000        S  False      1.267857    Mr
#      PassengerId  Survived  Pclass                                      Name  \
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket     Fare Embarked  Child  \
# 882  female  22.0      0      0             7552  10.5167        S  False
# 884    male  25.0      0      0  SOTON/OQ 392076   7.0500        S  False
# 885  female  39.0      0      5           382652  29.1250        Q  False
# 888  female  28.0      1      2       W./C. 6607  23.4500        S  False
# 890    male  32.0      0      0           370376   7.7500        Q  False
#
#      Fare_per_Age Title
# 882      0.478032  Miss
# 884      0.282000    Mr
# 885      0.746795   Mrs
# 888      0.837500  Miss
# 890      0.242188    Mr

# %% [markdown]
# ```pd.merge()``` merges 2 dataframes or Panda series much like a SQL JOIN.
#
# Since we only have a dataframe, let's create a new one with PassengerId and "PricePerPax" reusing the ```df.assign()``` code snippet.
#
# Then we'll add this new "PricePerPax" column to the main dataframe using ```pd.merge()``` using "PassengerId" as index.

# %%
# Create a dataframe adding the price_per_person

df_fares = df.assign(
    family_size = df['SibSp'] + df['Parch'] + 1,
    price_per_person = lambda x: x['Fare'] / x['family_size']
)

# Trim columns and rename

df_fares = df_fares[['PassengerId', 'price_per_person']].rename(columns={'price_per_person': 'PricePerPax'})

print(df_fares.head())

# Merge df_fares

df = pd.merge( df, df_fares, on='PassengerId', how='left' )

df.head()
# Out:
#    PassengerId  PricePerPax
# 0            1      3.62500
# 1            2     35.64165
# 2            3      7.92500
# 3            4     26.55000
# 4            5      8.05000
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Child  Fare_per_Age Title  \
# 0      0         A/5 21171   7.2500        S  False      0.329545    Mr
# 1      0          PC 17599  71.2833        C  False      1.875876   Mrs
# 2      0  STON/O2. 3101282   7.9250        S  False      0.304808  Miss
# 3      0            113803  53.1000        S  False      1.517143   Mrs
# 4      0            373450   8.0500        S  False      0.230000    Mr
#
#    PricePerPax
# 0      3.62500
# 1     35.64165
# 2      7.92500
# 3     26.55000
# 4      8.05000

# %% [markdown]
# ## 💾 Step 8: Exporting Data
#
# Function to explore:
# - df.to_csv("output.csv", index=False)

# %%
# Example: Save cleaned data
df.to_csv("titanic_cleaned.csv", index=False)

# %% [markdown]
# ## 🧩 Step 9: Summary
#
# Reflect on what you learned:
# - Which functions were most useful?
# - What insights did you gain from the Titanic dataset?

# %% [markdown]
# See comments above.
#
# Additionally, I was surprised and pleased to find that there were 6 unaccompanied children aboard the Titanic, and although they all belonged in 3rd class 4 of them managed to survive, even the youngest!
# ### *The odds are there to beat*.

# %%
unaccompanied_children = df.query("Age < 16 and SibSp == 0 and Parch == 0")
print("Number of children traveling alone aboard the Titanic:", unaccompanied_children.shape[0], "\n")
print("Unaccompanied children passenger list\n=======================================\n")
print(unaccompanied_children)
# Out:
# Number of children traveling alone aboard the Titanic: 6
#
# Unaccompanied children passenger list
# =======================================
#
#      PassengerId  Survived  Pclass                                  Name  \
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 731          732         0       3              Hassan, Mr. Houssein G N
# 777          778         1       3         Emanuel, Miss. Virginia Ethel
# 780          781         1       3                  Ayoub, Miss. Banoura
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Embarked  Child  \
# 14   female  14.0      0      0  350406   7.8542        S   True
# 22   female  15.0      0      0  330923   8.0292        Q   True
# 731    male  11.0      0      0    2699  18.7875        C   True
# 777  female   5.0      0      0  364516  12.4750        S   True
# 780  female  13.0      0      0    2687   7.2292        C   True
# 875  female  15.0      0      0    2667   7.2250        C   True
#
#      Fare_per_Age Title  PricePerPax
# 14       0.561014  Miss       7.8542
# 22       0.535280  Miss       8.0292
# 731      1.707955    Mr      18.7875
# 777      2.495000  Miss      12.4750
# 780      0.556092  Miss       7.2292
# 875      0.481667  Miss       7.2250
